# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
import seaborn as sns
from scipy.stats import skewnorm

# %% [markdown]
# https://rpruim.github.io/s341/S19/from-class/MathinRmd.html

# %% [markdown]
# ## Mean
#
# $\frac{\sum_X}n$
#
# **x-bar:** Sample Mean
#
# $\bar{x} = \frac{\sum_X}n$
#
# **mu:** Population Mean
#
# $\mu = \frac{\sum_X}N$
#
# Not resistant (to outliiers) & not stable
#
# Can make it stable by trimming 5% for resistance

# %% [markdown]
# ## Mode
#
# Most popular value

# %%
from statistics import mode

lst = [1,2,2,3,3,3]
max(set(lst), key=lst.count)
# Out:
# 3

# %% [markdown]
# ## Median
# 50th percentile
# resistant (to outliiers) & very stable

# %%
from statistics import median
# from numpy import median

median([1, 3, 5])
# Out:
# 3

# %% [markdown]
# ## Weighted AVG
#
# $\frac{\sum_{XW}}{\sum_W}$

# %%
( (4*0.1) + (3*0.2) + (3*0.7) ) / (0.1+ 0.2 + 0.7)
# Out:
# 3.0999999999999996

# %%
df = pd.DataFrame([16.99,10.34,21.01,21.01], columns=['bill'])

# %%
sns.histplot(np.random.normal(size=1000), kde=True)
# Out:
# <AxesSubplot:ylabel='Count'>

# %%
sns.histplot(skewnorm.rvs(10, size=1000), bins=50, kde=True)
# Out:
# <AxesSubplot:ylabel='Count'>

# %%
sns.histplot(skewnorm.rvs(-10, size=1000), bins=50, kde=True)
# Out:
# <AxesSubplot:ylabel='Count'>
